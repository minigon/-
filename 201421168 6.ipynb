# %%
# !pip install persim

# %%
# !pip install ripser

# %%
# !pip install scikit-tda

# %%
# !pip install tadasets

# %%
from sktda import *
import tadasets
from numpy import *
from pylab import *
from ripser import *
import persim as persim
from persim import plot_diagrams
from sklearn import datasets

# %%
#반지름 10, 노이즈 0.1인 구를 100개만듬
data = tadasets.sphere(n = 100, r = 10, noise = 0.1)
tadasets.plot3d(data)
torus = tadasets.torus(n = 1000, c = 2, a = 1, noise=None,)
tadasets.plot3d(torus)

# %%
data = tadasets.sphere(n = 100, r = 10, noise = 0)
dgms = ripser(data,maxdim = 3)['dgms']
plot_diagrams(dgms, show = True)
